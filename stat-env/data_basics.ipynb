# %%
import pandas as pd 
import matplotlib.pyplot as plt

url = "./data/nhanes_2015_2016.csv";
data = pd.read_csv(url);

# %%
y = data["BMXBMI"]

# %%
# create a figure 
plt.figure(figsize=(10,10));

x = range(data["BMXWT"].size)
y = data["BMXWT"]


plt.scatter(x,y,marker="o",s=0.8);

plt.title("My data plot ")
plt.grid(True)

plt.show();

# %%
y = y.dropna();
average = sum(y) / len(y)
print(average)
plt.plot(average);
# Out:
# 81.34267560889516
